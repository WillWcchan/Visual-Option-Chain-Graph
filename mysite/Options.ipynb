# %%
# Version 3.6.1    
import requests
import pandas
import json

response = requests.get('https://sandbox.tradier.com/v1/markets/options/chains',
    params={'symbol': 'NIO200814C00000500', 'expiration': '2020-08-14', 'greeks': 'true'},
    headers={'Authorization': 'Bearer ICTXIFyPoZuZMLnnjxURtZpXTXAR', 'Accept': 'application/json'}
)
json_response = response.json()

# with open('data.json','w') as outfile:
#     json.dump(json_response,outfile)
    
# df = pandas.read_json('data.json')
print(json.dumps(json_response, indent = 2))
# Out:
# {
#   "options": null
# }

# %%
import requests

response = requests.get('https://api.tradier.com/v1/markets/timesales',
    params={'symbol': 'NIO200814C00000500', 'interval': '1min', 'start': '2020-08-12 09:30', 'end': '2020-08-12 16:00', 'session_filter': 'open'},
    headers={'Authorization': 'Bearer SNcsTbvffbnL7Kre7K9FDRzNALjv', 'Accept': 'application/json'})
json_response = response.json()
print(response.status_code)
print(json.dumps(json_response, indent = 2))
# Out:
# 200
# {
#   "series": null
# }

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3]
y = [1,2,3]
z = [1,2,3]
plt.plot(x,y,z)
plt.title("test plot")
plt.xlabel("time")
plt.ylabel("price")
plt.legend(["this is y", "this is x"])
plt.show()

# %%
import requests
import json
from datetime import datetime

response = requests.get('https://sandbox.tradier.com/v1/markets/timesales',
            params={'symbol': 'DIS200807C00145000', 'interval': '5min', 'start': '2020-08-06 09:30', 'end': '2020-08-06 16:00', 'session_filter': 'all'},
            headers={'Authorization': 'Bearer ICTXIFyPoZuZMLnnjxURtZpXTXAR', 'Accept': 'application/json'}
)
json_response = response.json()
print(json.dumps(json_response, indent = 2))
# Out:
# {
#   "series": {
#     "data": [
#       {
#         "time": "2020-08-06T09:30:00",
#         "timestamp": 1596720600,
#         "price": 0.02,
#         "open": 0.02,
#         "high": 0.02,
#         "low": 0.02,
#         "close": 0.02,
#         "volume": 4,
#         "vwap": 0.02
#       },
#       {
#         "time": "2020-08-06T09:35:00",
#         "timestamp": 1596720900,
#         "price": 0.01,
#         "open": 0.01,
#         "high": 0.01,
#         "low": 0.01,
#         "close": 0.01,
#         "volume": 20,
#         "vwap": 0.01
#       },
#       {
#         "time": "2020-08-06T09:40:00",
#         "timestamp": 1596721200,
#         "price": 0.015,
#         "open": 0.01,
#         "high": 0.02,
#         "low": 0.01,
#         "close": 0.02,
#         "volume": 9,
#         "vwap": 0.01222222
#       },
#       {
#         "time": "2020-08-06T09:45:00",
#         "timestamp": 1596721500,
#         "price": 0.01,
#         "open": 0.01,
#         "high": 0.01,
# ...

# %%
from datetime import datetime
# print(json_response["series"]["data"][0])
# for data in list(json_response["series"]["data"]):
#     print(datetime.fromtimestamp(data['timestamp']))
timestamps = [str(datetime.fromtimestamp(data['timestamp']).strftime("%-I:%-M")) for data in json_response["series"]["data"]]
print(timestamps)
price = [data['price'] for data in json_response["series"]["data"]]

plt.plot(timestamps,price)
plt.xlabel("Time")
plt.xticks(rotation=45)
plt.ylabel("Price")
plt.show()
# Out:
# ['6:30', '6:35', '6:40', '6:45', '6:50', '6:55', '7:0', '7:5', '7:10', '7:20', '7:25', '7:30', '7:45', '8:5', '8:10', '8:30', '8:45', '8:55', '9:20', '9:45', '10:10', '10:15', '10:25', '10:35', '10:40', '10:50', '11:0', '11:15', '11:20', '11:25', '11:30', '11:40', '11:45', '12:0', '12:20', '12:30', '12:40', '12:45']

# %%
from __future__ import print_function
import time
import intrinio_sdk as intrinio
from intrinio_sdk.rest import ApiException

intrinio.ApiClient().configuration.api_key['api_key'] = 'OmNmMGEzYjY5MTI1OTg3YTQyMThkYmUwNDU4MzRlYWFk'

symbol = 'MSFT'

response = intrinio.OptionsApi().get_options_expirations(symbol, after="2020-08-04")
print(response)
# Out:
# {'expirations': ['2020-08-07']}

# %%
import matplotlib.pyplot as plt
import numpy as np

# fig1,(ax1,ax2,ax3) = plt.subplots(nrows=1, ncols=3)
# ax1.plot([1,2,3],[4,5,6])
# ax2.plot([8,9,10],[11,12,13])
plt.plot(['09:30:00', '09:35:00', '09:40:00', '09:45:00', '09:50:00', '10:00:00', '10:05:00', '10:10:00', '10:30:00', '10:50:00', '10:55:00', '11:00:00', '11:05:00', '11:55:00', '12:00:00', '12:10:00', '12:25:00', '12:40:00', '12:45:00', '12:50:00', '12:55:00', '13:00:00', '13:05:00', '13:10:00', '13:15:00', '13:20:00', '13:30:00', '13:40:00', '13:55:00', '14:05:00', '14:15:00', '14:20:00', '14:25:00', '14:35:00', '14:50:00', '14:55:00', '15:15:00', '15:30:00', '15:35:00', '15:40:00', '15:50:00', '15:55:00'],
        [0.02, 0.01, 0.015, 0.01, 0.01, 0.015, 0.02, 0.02, 0.02, 0.02, 0.02, 0.01, 0.03, 0.01, 0.01, 0.03, 0.02, 0.03, 0.045, 0.04, 0.05500000000000001, 0.05, 0.055, 0.055, 0.06, 0.05, 0.05, 0.03, 0.035, 0.05, 0.05, 0.05, 0.05, 0.06, 0.05, 0.04, 0.06, 0.05, 0.04, 0.04, 0.03, 0.05])
plt.show()

# %%
import requests

response = requests.get('https://sandbox.tradier.com/v1/markets/options/expirations',
    params={'symbol': 'MSFT', 'includeAllRoots': 'false', 'strikes': 'false'},
    headers={'Authorization': 'Bearer ICTXIFyPoZuZMLnnjxURtZpXTXAR', 'Accept': 'application/json'}
)
json_response = response.json()
print(json.dumps(json_response, indent = 2))
# Out:
# {
#   "expirations": {
#     "date": [
#       "2020-08-14",
#       "2020-08-21",
#       "2020-08-28",
#       "2020-09-04",
#       "2020-09-11",
#       "2020-09-18",
#       "2020-09-25",
#       "2020-10-16",
#       "2020-11-20",
#       "2020-12-18",
#       "2021-01-15",
#       "2021-02-19",
#       "2021-03-19",
#       "2021-06-18",
#       "2021-07-16",
#       "2021-09-17",
#       "2022-01-21",
#       "2022-03-18",
#       "2022-06-17",
#       "2022-09-16"
#     ]
#   }
# }

# %%
import requests

response = requests.get('https://api.tradier.com/v1/markets/quotes',
    params={'symbols': 'AAPL', 'greeks': 'false'},
    headers={'Authorization': 'Bearer SNcsTbvffbnL7Kre7K9FDRzNALjv', 'Accept': 'application/json'}
)
json_response = response.json()
print(json.dumps(json_response, indent = 2))
# Out:
# {
#   "quotes": {
#     "quote": {
#       "symbol": "AAPL",
#       "description": "Apple Inc",
#       "exch": "Q",
#       "type": "stock",
#       "last": 452.095,
#       "change": 14.6,
#       "volume": 31190398,
#       "open": 441.99,
#       "high": 453.1,
#       "low": 441.19,
#       "close": null,
#       "bid": 452.06,
#       "ask": 452.13,
#       "change_percentage": 3.34,
#       "average_volume": 32342116,
#       "last_volume": 100,
#       "trade_date": 1597256790761,
#       "prevclose": 437.5,
#       "week_52_high": 457.65,
#       "week_52_low": 199.67,
#       "bidsize": 4,
#       "bidexch": "Q",
#       "bid_date": 1597256790000,
#       "asksize": 2,
#       "askexch": "Z",
#       "ask_date": 1597256790000,
#       "root_symbols": "AAPL"
#     }
#   }
# }

# %%
import requests

response = requests.get('https://api.tradier.com/v1/markets/timesales',
           params={'symbol': 'NIO200814C00013000', 'interval': '5min', 'start': '2020-08-12 09:30', 'end': '2020-08-12 16:00', 'session_filter': 'all'},
           headers={'Authorization': 'Bearer SNcsTbvffbnL7Kre7K9FDRzNALjv', 'Accept': 'application/json'})
json_response = response.json()
print(response.status_code)
print(json.dumps(json_response, indent = 2))
# Out:
# 200
# {
#   "series": {
#     "data": [
#       {
#         "time": "2020-08-12T09:30:00",
#         "timestamp": 1597239000,
#         "price": 0.655,
#         "open": 0.73,
#         "high": 0.74,
#         "low": 0.57,
#         "close": 0.57,
#         "volume": 652,
#         "vwap": 0.6632515
#       },
#       {
#         "time": "2020-08-12T09:35:00",
#         "timestamp": 1597239300,
#         "price": 0.525,
#         "open": 0.58,
#         "high": 0.64,
#         "low": 0.41,
#         "close": 0.44,
#         "volume": 350,
#         "vwap": 0.5033143
#       },
#       {
#         "time": "2020-08-12T09:40:00",
#         "timestamp": 1597239600,
#         "price": 0.37,
#         "open": 0.43,
#         "high": 0.46,
#         "low": 0.28,
#         "close": 0.35,
#         "volume": 1235,
#         "vwap": 0.3446883
#       },
#       {
#         "time": "2020-08-12T09:45:00",
#         "timestamp": 1597239900,
#         "price": 0.39,
#         "open": 0.35,
# ...

# %%
import requests
import json

response = requests.get('https://api.tradier.com/v1/markets/timesales',
    params={'symbol': 'JNJ200814P00150000', 'interval': '1min', 'start': '2020-08-12 09:30', 'end': '2020-08-12 13:00', 'session_filter': 'open'},
    headers={'Authorization': 'Bearer SNcsTbvffbnL7Kre7K9FDRzNALjv', 'Accept': 'application/json'}
)

json_response = response.json()
print(json.dumps(json_response, indent = 2))
print(len(json_response["series"]["data"]))
# Out:
# {
#   "series": {
#     "data": [
#       {
#         "time": "2020-08-12T10:38:00",
#         "timestamp": 1597243080,
#         "price": 1.42,
#         "open": 1.42,
#         "high": 1.42,
#         "low": 1.42,
#         "close": 1.42,
#         "volume": 2,
#         "vwap": 1.42
#       },
#       {
#         "time": "2020-08-12T10:42:00",
#         "timestamp": 1597243320,
#         "price": 1.48,
#         "open": 1.48,
#         "high": 1.48,
#         "low": 1.48,
#         "close": 1.48,
#         "volume": 2,
#         "vwap": 1.48
#       },
#       {
#         "time": "2020-08-12T11:02:00",
#         "timestamp": 1597244520,
#         "price": 1.14,
#         "open": 1.14,
#         "high": 1.14,
#         "low": 1.14,
#         "close": 1.14,
#         "volume": 2,
#         "vwap": 1.14
#       },
#       {
#         "time": "2020-08-12T11:09:00",
#         "timestamp": 1597244940,
#         "price": 1.19,
#         "open": 1.19,
#         "high": 1.19,
# ...
